# %% [markdown]
# # Get import

# %%
try:
    from kmdvalg import kommune
except ImportError:
    import sys, os
    sys.path.append( os.getcwd()+os.sep+"..")
    print(sys.path)
# Out:
# ['', '/Users/tlinnet/anaconda/envs/kmdvalg/lib/python35.zip', '/Users/tlinnet/anaconda/envs/kmdvalg/lib/python3.5', '/Users/tlinnet/anaconda/envs/kmdvalg/lib/python3.5/plat-darwin', '/Users/tlinnet/anaconda/envs/kmdvalg/lib/python3.5/lib-dynload', '/Users/tlinnet/anaconda/envs/kmdvalg/lib/python3.5/site-packages', '/Users/tlinnet/anaconda/envs/kmdvalg/lib/python3.5/site-packages/IPython/extensions', '/Users/tlinnet/.ipython', '/Users/tlinnet/software/kmdvalg/examples/..']

# %% [markdown]
# # Get import

# %%
from kmdvalg import kommune
import bokeh.plotting as bplt

# %% [markdown]
# # Get kommune list

# %%
data = kommune.data()
# Get info
#df = data.get_kommuner_df()
df = data.get_kommuner_df(make=True)
# Out:
# Kommune data missing. Creating it.
# Reading for: ['A', 'Albertslund', 'https://www.kmdvalg.dk/kv/2017/K84982165.htm']
# Reading for: ['A', 'Allerød', 'https://www.kmdvalg.dk/kv/2017/K84982201.htm']
# Reading for: ['A', 'Assens', 'https://www.kmdvalg.dk/kv/2017/K84733420.htm']
# Reading for: ['B', 'Ballerup', 'https://www.kmdvalg.dk/kv/2017/K84982151.htm']
# Reading for: ['B', 'Billund', 'https://www.kmdvalg.dk/kv/2017/K84733530.htm']
# Reading for: ['B', 'Bornholm', 'https://www.kmdvalg.dk/kv/2017/K84982400.htm']
# Reading for: ['B', 'Brøndby', 'https://www.kmdvalg.dk/kv/2017/K84982153.htm']
# Reading for: ['B', 'Brønderslev', 'https://www.kmdvalg.dk/kv/2017/K84712810.htm']
# Reading for: ['D', 'Dragør', 'https://www.kmdvalg.dk/kv/2017/K84982155.htm']
# Reading for: ['E', 'Egedal', 'https://www.kmdvalg.dk/kv/2017/K84982240.htm']
# Reading for: ['E', 'Esbjerg', 'https://www.kmdvalg.dk/kv/2017/K84733561.htm']
# Reading for: ['F', 'Fanø', 'https://www.kmdvalg.dk/kv/2017/K84733563.htm']
# Reading for: ['F', 'Favrskov', 'https://www.kmdvalg.dk/kv/2017/K84713710.htm']
# Reading for: ['F', 'Faxe', 'https://www.kmdvalg.dk/kv/2017/K84979320.htm']
# Reading for: ['F', 'Fredensborg', 'https://www.kmdvalg.dk/kv/2017/K84982210.htm']
# Reading for: ['F', 'Fredericia', 'https://www.kmdvalg.dk/kv/2017/K84733607.htm']
# Reading for: ['F', 'Frederiksberg', 'https://www.kmdvalg.dk/kv/2017/K84982147.htm']
# Reading for: ['F', 'Frederikshavn', 'https://www.kmdvalg.dk/kv/2017/K84712813.htm']
# Reading for: ['F', 'Frederikssund', 'https://www.kmdvalg.dk/kv/2017/K84982250.htm']
# Reading for: ['F', 'Furesø', 'https://www.kmdvalg.dk/kv/2017/K84982190.htm']
# Reading for: ['F', 'Faaborg-Midtfyn', 'https://www.kmdvalg.dk/kv/2017/K84733430.htm']
# Reading for: ['S', 'Syddjurs', 'https://www.kmdvalg.dk/kv/2017/K84713706.htm']
# Reading for: ['S', 'Sønderborg', 'https://www.kmdvalg.dk/kv/2017/K84733540.htm']
# Reading for: ['T', 'Thisted', 'https://www.kmdvalg.dk/kv/2017/K84712787.htm']
# Reading for: ['T', 'Tønder', 'https://www.kmdvalg.dk/kv/2017/K84733550.htm']
# Reading for: ['T', 'Tårnby', 'https://www.kmdvalg.dk/kv/2017/K84982185.htm']
# Reading for: ['V', 'Vallensbæk', 'https://www.kmdvalg.dk/kv/2017/K84982187.htm']
# Reading for: ['V', 'Varde', 'https://www.kmdvalg.dk/kv/2017/K84733573.htm']
# Reading for: ['V', 'Vejen', 'https://www.kmdvalg.dk/kv/2017/K84733575.htm']
# Reading for: ['V', 'Vejle', 'https://www.kmdvalg.dk/kv/2017/K84733630.htm']
# Reading for: ['V', 'Vesthimmerlands', 'https://www.kmdvalg.dk/kv/2017/K84712820.htm']
# Reading for: ['V', 'Viborg', 'https://www.kmdvalg.dk/kv/2017/K84713791.htm']
# Reading for: ['V', 'Vordingborg', 'https://www.kmdvalg.dk/kv/2017/K84979390.htm']
# Reading for: ['Æ', 'Ærø', 'https://www.kmdvalg.dk/kv/2017/K84733492.htm']
# Reading for: ['Å', 'Aabenraa', 'https://www.kmdvalg.dk/kv/2017/K84733580.htm']
# Reading for: ['Å', 'Aalborg', 'https://www.kmdvalg.dk/kv/2017/K84712851.htm']
# Reading for: ['Å', 'Aarhus', 'https://www.kmdvalg.dk/kv/2017/K84713751.htm']

# %% [markdown]
# # Get kommune map

# %%
#kmap = kommune.kmap(make=True)
kmap = kommune.kmap()

# Make map data
kmap.make_map_source(df=df)

fig = kmap.get_map()
# Out:
# Kommune shapefile exists. Reading it.

# %% [markdown]
# # Show output

# %%
# Get output. Either to Jupyter notebook or html file 
if True:
    if kommune.check_isnotebook():
        from bokeh.io import output_notebook
        output_notebook()
        bplt.show(fig, notebook_handle=True)
    else:
        # Save to html
        filename = "bokeh.html"
        bplt.output_file(filename)
        bplt.save(fig)
        # And auto open
        import webbrowser, os
        webbrowser.open('file://' + os.path.realpath(filename))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="97b05e3d-8442-4a41-8566-c38a21037a46">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="92d97ccd-9b55-4ac6-a5a7-1ccbe8f8c652"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("92d97ccd-9b55-4ac6-a5a7-1ccbe8f8c652");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("92d97ccd-9b55-4ac6-a5a7-1ccbe8f8c652");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '92d97ccd-9b55-4ac6-a5a7-1ccbe8f8c652' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"98b3a448-77aa-4805-906b-6722941a54e8":{"roots":{"references":[{"attributes":{},"id":"09f7487c-eed5-4634-8d18-fba497f08b81","type":"LinearScale"},{"attributes":{},"id":"86f32018-5825-422c-9dfd-7622445dedbd","type":"RedoTool"},{"attributes":{"callback":null,"point_policy":"follow_mouse","tooltips":[["Navn","@kommuner"],["Dato","@kommuner_dates"],["stemme pct","@stemme_pct %"]]},"id":"e83eb2d0-0d70-47aa-8a41-9d64f91c0276","type":"HoverTool"},{"attributes":{"high":90.0,"low":50.0,"palette":["#a50026","#d73027","#f46d43","#fdae61","#fee08b","#ffffbf","#d9ef8b","#a6d96a","#66bd63","#1a9850","#006837"]},"id":"6ff33b35-61d0-4e98-b04e-23161ecbc29c","type":"LinearColorMapper"},{"attributes":{"callback":null,"column_names":["x_lon","kommuner","kommuner_dates","y_lat","stemme_pct"],"data":{"kommuner":["Norddjurs","Holb\u00e6k","Holstebro","Esbjerg","Lolland","Odsherred","Randers","Svendborg","Nordfyns","Langeland","Favrskov","Ballerup","Kerteminde","Kerteminde","Faxe","Faaborg-Midtfyn","Lolland","Kalundborg","K\u00f8benhavn","N\u00e6stved","Nordfyns","Lyngby-Taarb\u00e6k","Roskilde","Faaborg-Midtfyn","Faaborg-Midtfyn","Faaborg-Midtfyn","Kalundborg","Nordfyns","K\u00f8benhavn","K\u00f8benhavn","Slagelse","Slagelse","Rudersdal","Ringsted","Holb\u00e6k","Horsens","Aabenraa","Norddjurs","Holstebro","\u00c6r\u00f8","Gribskov","Aalborg","Lolland","Hiller\u00f8d","Stevns","Aarhus","Assens","Skanderborg","Svendborg","Struer","Aller\u00f8d","Hedensted","Hj\u00f8rring","Lemvig","Varde","L\u00e6s\u00f8","Odense","Fredericia","Vallensb\u00e6k","Vordingborg","Vordingborg","Vejen","Gladsaxe","Albertslund","Nyborg","Guldborgsund","Frederikshavn","Helsing\u00f8r","Vesthimmerlands","Haderslev","Viborg","Kalundborg","Horsens","Slagelse","Slagelse","Slagelse","Slagelse","H\u00f8je-Taastrup","Kolding","Kolding","Mariagerfjord","Billund","Lolland","Mors\u00f8","L\u00e6s\u00f8","T\u00f8nder","Svendborg","Odder","Vordingborg","T\u00e5rnby","Odder","Vordingborg","Vordingborg","Vordingborg","Vordingborg","Halsn\u00e6s","Hedensted","Herlev","Kerteminde","R\u00f8dovre","Skive","Br\u00f8ndby","Vesthimmerlands","Varde","Vejle","Bornholm","Faaborg-Midtfyn","Greve","Slagelse","Struer","N\u00e6stved","Solr\u00f8d","Fan\u00f8","Frederikssund","Aalborg","S\u00f8nderborg","Aabenraa","Fures\u00f8","Lolland","Sams\u00f8","\u00c6r\u00f8","Jammerbugt","Middelfart","Mors\u00f8","T\u00e5rnby","Middelfart","Christians\u00f8","Langeland","Silkeborg","Fredensborg","Haderslev","Nordfyns","Ringk\u00f8bing-Skjern","Frederikssund","Frederikssund","Thisted","Gentofte","Lolland","Middelfart","Frederiksberg","Sams\u00f8","Svendborg","Syddjurs","Br\u00f8nderslev","Hvidovre","N\u00e6stved","N\u00e6stved","Ikast-Brande","Egedal","Aalborg","Rebild","Lolland","Assens","T\u00e5rnby","Ringk\u00f8bing-Skjern","Struer","Odder","Ish\u00f8j","Glostrup","Vesthimmerlands","S\u00f8nderborg","H\u00f8rsholm","Lolland","Sams\u00f8","Svendborg","Svendborg","Vordingborg","Struer","K\u00f8ge","Langeland","Drag\u00f8r","Guldborgsund","Skive","Herning","Sor\u00f8","K\u00f8benhavn","Lejre"],"kommuner_dates":["2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017-10-02","2017- ...
